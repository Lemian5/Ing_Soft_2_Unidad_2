# %% [markdown]
# <a href="https://colab.research.google.com/github/Lemian5/Ing_Soft_2_Unidad_2/blob/main/Superservicios_Ventas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Utilizamos la funcion files.upload() para cargar el archivo desde nuestro PC
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8f5ca9ab-0cd7-4944-8444-1fede7f2e5bf" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8f5ca9ab-0cd7-4944-8444-1fede7f2e5bf">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Especifica la URL del archivo CSV
url = "/content/Superservicios.csv"
# Lee el archivo CSV desde la URL en un DataFrame
df = pd.read_csv(url)

# Muestra los primeros registros del DataFrame
df.head(15)
# Out:
#     ID_EMPRESA                                            EMPRESA  ANIO  MES  \
# 0       3206.0                                     ECOPETROL S.A.  2017    7
# 1      21870.0                        REFINERIA DE CARTAGENA S.A.  2017    1
# 2       1638.0         COMPAÑIA DE ALMACENAMIENTO DE GAS S.A. ESP  2017    9
# 3        479.0                     GASES DE ANTIOQUIA S.A. E.S.P.  2017    6
# 4      32073.0                                   MEGAS S.A.S. ESP  2017    6
# 5        479.0                     GASES DE ANTIOQUIA S.A. E.S.P.  2017    8
# 6       1345.0                         COLGAS DE OCCIDENTE SA ESP  2017    6
# 7       3206.0                                     ECOPETROL S.A.  2017    6
# 8       1635.0            ALMACENADORA DE GASES DE APIAY S.A. ESP  2017    2
# 9       3206.0                                     ECOPETROL S.A.  2017    2
# 10     23312.0                            INVERSIONES GLP SAS ESP  2017    4
# ...

# %%
# Eliminamos la columna NOMBRE_PUNTO_ENTREGA
df = df.drop(columns=['NOMBRE_PUNTO_ENTREGA'])

# %%
# Nos muestra los datos con la columna eliminada
df.head()
# Out:
#    ID_EMPRESA                                     EMPRESA  ANIO  MES  \
# 0      3206.0                              ECOPETROL S.A.  2017    7
# 1     21870.0                 REFINERIA DE CARTAGENA S.A.  2017    1
# 2      1638.0  COMPAÑIA DE ALMACENAMIENTO DE GAS S.A. ESP  2017    9
# 3       479.0              GASES DE ANTIOQUIA S.A. E.S.P.  2017    6
# 4     32073.0                            MEGAS S.A.S. ESP  2017    6
#
#                     OPC CODIGO_FP  NIT_DEL_COMPRADOR  \
# 0           ECP-2017-10       CUS         8605088925
# 1      VCM-GNR-2017-005       CAR         8902009190
# 2      VCM-GNR-2017-010       CUS         9008636497
# 3                   NaN       CUS         8903106886
# 4  VG2017003-9009135075       CUS         9009135075
#
#               RAZON_SOCIAL_DEL_COMPRADOR         TIPO_DEL_COMPRADOR  \
# 0  COMPAï¿¿IA DE ALMACENAMIENTO DE GAS S  COMERCIALIZADOR MAYORISTA
# 1            GASES DE SANTANDER S.A. ESP  COMERCIALIZADOR MAYORISTA
# ...

# %%
# Cambiamos el nombre de la columna "CODIGO_EP por EPCOD"
df.rename(columns={'CODIGO_FP': 'EPCOD'}, inplace=True)

# %%
df.head()
# Out:
#    ID_EMPRESA                                     EMPRESA  ANIO  MES  \
# 0      3206.0                              ECOPETROL S.A.  2017    7
# 1     21870.0                 REFINERIA DE CARTAGENA S.A.  2017    1
# 2      1638.0  COMPAÑIA DE ALMACENAMIENTO DE GAS S.A. ESP  2017    9
# 3       479.0              GASES DE ANTIOQUIA S.A. E.S.P.  2017    6
# 4     32073.0                            MEGAS S.A.S. ESP  2017    6
#
#                     OPC EPCOD  NIT_DEL_COMPRADOR  \
# 0           ECP-2017-10   CUS         8605088925
# 1      VCM-GNR-2017-005   CAR         8902009190
# 2      VCM-GNR-2017-010   CUS         9008636497
# 3                   NaN   CUS         8903106886
# 4  VG2017003-9009135075   CUS         9009135075
#
#               RAZON_SOCIAL_DEL_COMPRADOR         TIPO_DEL_COMPRADOR  \
# 0  COMPAï¿¿IA DE ALMACENAMIENTO DE GAS S  COMERCIALIZADOR MAYORISTA
# 1            GASES DE SANTANDER S.A. ESP  COMERCIALIZADOR MAYORISTA
# ...
